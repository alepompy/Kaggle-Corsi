# %% [markdown]
# ### Funzioni

# %%
# Define the function
def add_three(input_var):
    output_var = input_var + 3
    return output_var

# %% [markdown]
# Ogni funzione è composta da due parti: un'intestazione e un corpo.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **header**
#
# L'intestazione della funzione definisce il nome della funzione e i suoi argomenti.
#
# Ogni intestazione di funzione inizia con def, che indica a Python che stiamo per definire una funzione.
#
# Nell'esempio, il nome della funzione è add_three.
#
# Nell'esempio, l'argomento è input_var. L'argomento è il nome della variabile che verrà utilizzata come input della funzione. È sempre racchiuso tra parentesi che compaiono subito dopo il nome della funzione. (Si noti che una funzione può anche non avere argomenti o avere più argomenti. Ne vedremo alcuni esempi più avanti nella lezione).
#
# Per ogni funzione, le parentesi che racchiudono gli argomenti della funzione devono essere seguite dai due punti :.

# %% [markdown]
# **body**
#
# Il corpo della funzione specifica il lavoro che la funzione svolge.
#
# Ogni riga di codice nel corpo della funzione deve essere rientrata esattamente di quattro spazi. Per farlo, basta premere quattro volte la barra spaziatrice o premere una volta il tasto "Tab" sulla tastiera. (Con l'approfondimento di Python, potrebbe essere necessario rientrare il codice di più di quattro spazi, ma questo verrà spiegato più avanti nel corso).
#
# La funzione esegue il lavoro eseguendo tutte le righe rientrate dall'alto verso il basso.
#
# Prende come input l'argomento, che nell'esempio è input_var.
#
# La funzione crea una nuova variabile output_var con il calcolo output_var = input_var + 3.
#
# Quindi, l'ultima riga di codice, chiamata istruzione return, restituisce semplicemente il valore in output_var come output della funzione.
#
# La cella di codice precedente definisce solo la funzione, ma non la esegue. I dettagli del corpo della funzione avranno più senso dopo la prossima cella di codice, quando la funzione verrà effettivamente eseguita.

# %% [markdown]
# **Call a function**
#
# Quando si esegue una funzione, si parla anche di "calling" della funzione.
#
# Nella cella di codice sottostante, eseguiamo la funzione con 10 come valore di ingresso. Definiamo una nuova variabile new_number che viene impostata come uscita della funzione.

# %%
# Run the function with 10 as input
new_number = add_three(10)

# Check that the value is 13, as expected
print(new_number)
# Out:
# 13

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# In dettaglio,
#
# - add_three(10) è il valore che otteniamo come output quando forniamo 10 come valore di input_var e chiamiamo la funzione add_three(). Quando la funzione viene eseguita, esegue tutto il codice nel suo corpo, dall'inizio alla fine:
#  - Per prima cosa calcola output_var = input_var + 3, che imposta output_var = 13.
#  - L'ultima riga di codice è l'istruzione return, che restituisce il valore di output_var, che è 13.
#
# Impostando nuovo_numero = add_three(10), si imposta nuovo_numero = 13.
#
# Funzione add_three(), usiamo delle parentesi di chiusura vuote dopo il nome della funzione. Questo è coerente con il modo in cui generalmente si scrivono le spiegazioni del codice Python e le parentesi vuote chiariscono che ci stiamo riferendo a una funzione, invece che a una variabile o a un altro oggetto Python. Queste parentesi dovrebbero essere sempre vuote, anche se la funzione ha degli argomenti.

# %% [markdown]
# Supponiamo che stiate aiutando un amico a calcolare la sua busta paga settimanale al netto delle tasse.
#
# - L'amico si trova in una fascia fiscale del 12% (in altre parole, il 12% del suo stipendio viene tassato e lui ne porta a casa solo l'88%).
# - Sono pagati a ore, con una tariffa di 15 dollari/ora.
#
# La funzione seguente calcola la busta paga in base al numero di ore lavorate. La funzione è più complicata rispetto al primo esempio, perché contiene più righe di codice e commenti. Come nell'esempio precedente, la funzione ha un unico argomento (num ore). Nel corpo della funzione, noi:
#
#  - Usare il valore di num_hours per specificare il valore di una nuova variabile pay_pretax.
#  - Utilizzare il valore di pay_pretax per specificare il valore di una nuova variabile pay_aftertax.
#  - Restituire il valore della variabile pay_aftertax.

# %%
def get_pay(num_hours):
    # Pre-tax pay, based on receiving $15/hour
    pay_pretax = num_hours * 15
    # After-tax pay, based on being in 12% tax bracket
    pay_aftertax = pay_pretax * (1 - .12)
    return pay_aftertax

# %%
# Calculate pay based on working 40 hours
pay_fulltime = get_pay(40)
print(pay_fulltime)
# Out:
# 528.0

# %% [markdown]
# Chiamiamo questa funzione nello stesso modo in cui abbiamo chiamato la prima funzione. La cella di codice successiva calcola lo stipendio, basato su 40 ore di lavoro. (Al netto delle tasse, è di 528 dollari).

# %%
pay_parttime = get_pay(32)
print(pay_parttime)
# Out:
# 422.4

# %% [markdown]
# Avendo scritto una funzione, è possibile calcolare la retribuzione per diverse ore senza dover riscrivere tutto il codice dei calcoli.
#
# Le funzioni possono aiutare a evitare errori nel codice e a risparmiare molto tempo. In generale, quando si scrive, si dovrebbe puntare a scrivere il meno possibile, perché ogni volta che si digita un calcolo è un'altra occasione per introdurre accidentalmente un refuso o un errore.

# %% [markdown]
# Le variabili definite all'interno del corpo della funzione non possono essere accessibili al di fuori della funzione. Ad esempio, la cella di codice successiva presenta un errore, perché pay_aftertax esiste solo all'interno della funzione.
# Si otterrà lo stesso errore se si cerca di stampare pay_pretax o num_hours. Per questo motivo, se avete bisogno di informazioni da una funzione, dovete assicurarvi che queste appaiano nell'istruzione return alla fine della funzione.
#
# Per 'scope' di una variabile si intende la parte del codice in cui è accessibile. Le variabili definite all'interno di una funzione (come pay_aftertax) hanno un ambito locale solo di quella funzione. Tuttavia, come abbiamo visto, le variabili definite al di fuori di tutte le funzioni (come pay_parttime) hanno un ambito globale e possono essere accessibili ovunque.

# %% [markdown]
# **Più variabili**
#
# Per definire una funzione con più argomenti, è sufficiente aggiungere altri argomenti all'interno delle parentesi nel titolo della funzione e separarli con una virgola.
#
# Lo facciamo con la funzione get_pay_with_more_inputs(), che calcola una busta paga settimanale in base a tre argomenti:
#
# - num_hours = numero di ore lavorate in una settimana
# - hourly_wage = il salario orario (in dollari/ora)
# - tax_bracket = percentuale del salario che viene tolta per le tasse

# %%
def get_pay_with_more_inputs(num_hours, hourly_wage, tax_bracket):
    # Pre-tax pay
    pay_pretax = num_hours * hourly_wage
    # After-tax pay
    pay_aftertax = pay_pretax * (1 - tax_bracket)
    return pay_aftertax

# %%
higher_pay_aftertax = get_pay_with_more_inputs(40, 24, .22)
print(higher_pay_aftertax)
# Out:
# 748.8000000000001

# %% [markdown]
# Quindi, per chiamare la funzione, è necessario fornire un valore per ciascun input, sempre separato da una virgola.
#
# Nella cella di codice qui sotto, calcoliamo la retribuzione al netto delle tasse per una persona che lavora 40 ore, guadagna 24 dollari l'ora e si trova in una fascia fiscale del 22%.

# %%
same_pay_fulltime = get_pay_with_more_inputs(40, 15, .12)
print(same_pay_fulltime)
# Out:
# 528.0

# %% [markdown]
# A seconda di come si intende utilizzare questa nuova funzione get_pay_with_more_inputs(), può essere più utile della funzione originale get_pay(), perché affronta più casi. Invece di assumere potenzialmente in modo errato la retribuzione oraria e la fascia fiscale, la nuova funzione consente all'utente di specificare i valori corretti. Tuttavia, se si è certi che il salario orario e la fascia fiscale non dovranno cambiare, la nuova funzione è più complicata del necessario. In generale, quando si definiscono le funzioni, è necessario considerare quanta flessibilità è necessaria, in base al caso d'uso.

# %% [markdown]
# **no argument**

# %% [markdown]
# Si noti che è possibile definire funzioni senza argomenti e che non hanno un'istruzione di ritorno. La funzione print_hello() nella cella di codice sottostante ne è un esempio.

# %%
# Define the function with no arguments and with no return
def print_hello():
    print("Hello, you!")
    print("Good morning!")
    
# Call the function
print_hello()
# Out:
# Hello, you!
# Good morning!

# %% [markdown]
# ## Esercizi

# %%
# Set up the exercise
import math
from learntools.core import binder
binder.bind(globals())
from learntools.intro_to_programming.ex2 import *
print('Setup complete.')
# Out:
# Setup complete.

# %% [markdown]
# ### Domanda 1

# %% [markdown]
# Create una funzione get_expected_cost() con due argomenti:
#
# - beds = numero di camere da letto
# - baths = numero di bagni
#
# Dovrebbe restituire il costo previsto di una casa con quel numero di camere da letto e di bagni. Si supponga che:
#
# - il costo previsto per una casa con 0 camere da letto e 0 bagni è di 80000.
# - ogni camera da letto aggiunge 30000 al costo previsto
# - ogni bagno aggiunge 10000 al costo previsto.
#
# Per esempio,
# - una casa con 1 camera da letto e 1 bagno ha un costo previsto di 120000,
# - una casa con 2 camere da letto e 1 bagno ha un costo previsto di 150000.

# %%
# TODO: Complete the function
def get_expected_cost(beds, baths):
    value = 80000 + beds*30000 + baths*10000
    return value

# Check your answer 
q1.check()
# Out:
# Correct

# %% [markdown]
# ### Domanda 2

# %% [markdown]
# State pensando di acquistare una casa e volete farvi un'idea di quanto spenderete in base al numero di camere da letto e di bagni. State cercando di decidere tra quattro diverse opzioni:
#
# - Opzione 1: casa con due camere da letto e tre bagni
# - Opzione 2: casa con tre camere da letto e due bagni
# - Opzione 3: casa con tre camere da letto e tre bagni
# - Opzione 4: casa con tre camere da letto e quattro bagni.
#
#
# Utilizzate la funzione get_expected_cost() che avete definito nella domanda 1 per impostare le opzion_1, option_2, option_3 e option_4 al costo atteso di ciascuna opzione.

# %%
# TODO: Use the get_expected_cost function to fill in each value
option_one = get_expected_cost(2, 3)
option_two = get_expected_cost(3, 2)
option_three = get_expected_cost(3, 3)
option_four = get_expected_cost(3, 4)

print(option_one)
print(option_two)
print(option_three)
print(option_four)

# Check your answer
q2.check()
# Out:
# 170000
# 190000
# 200000
# 210000
# Correct

# %% [markdown]
# ### Domanda 3

# %% [markdown]
# Siete un arredatore di case e vorreste usare Python per semplificare il vostro lavoro. In particolare, state creando uno strumento che intendete utilizzare per calcolare il costo della pittura di una stanza.
#
# Come primo passo, definite una funzione get_cost() che prenda come input:
#
# - sqft_walls = feets quadrati totali di pareti da dipingere
# - sqft_ceiling = feets quadrati di soffitto da dipingere
# - sqft_per_gallon = numero di feets quadrati che si possono coprire con un gallone di vernice
# - costo_per_gallone = costo (in dollari) di un gallone di vernice
#
# Dovrebbe restituire il costo (in dollari) di una mano di vernice su tutte le pareti e sul soffitto. Si supponga di poter acquistare l'esatta quantità di vernice necessaria, in modo da poter acquistare galloni parziali (ad esempio, se si ha bisogno di 7,523 galloni, si può acquistare quella quantità esatta, invece di doverne acquistare 8 galloni e sprecare un po' di vernice). Non arrotondare la risposta.

# %%
# TODO: Finish defining the function
def get_cost(sqft_walls, sqft_ceiling, sqft_per_gallon, cost_per_gallon):
    cost = ((sqft_ceiling + sqft_walls)/sqft_per_gallon)*cost_per_gallon
    return cost
# somma dei feets totali da dipingere (pareti e soffitto) diviso n. feets che si coprono con 1 gallone, tutto moltiplicato 
        # per il costo di 1 gallone 

# Check your answer
q3.check()
# Out:
# Correct

# %% [markdown]
# ### Domanda 4

# %% [markdown]
# Usate la funzione get_cost() che avete definito nella Domanda 3 per calcolare il costo dell'applicazione di una mano di vernice a una stanza con:
#
# - 432 metri quadrati di pareti e
# - 144 metri quadrati di soffitto.
#
# Si supponga che un gallone di vernice copra:
# - 400 piedi quadrati
# - costi 15 dollari.
#
# Come nella domanda 3, si supponga di poter acquistare galloni parziali di vernice. Non arrotondare la risposta.

# %%
# TODO: Set the project_cost variable to the cost of the project
project_cost = get_cost(432, 144, 400, 15)

# Check your answer
q4.check()
# Out:
# Correct

# %% [markdown]
# ### Domanda 5

# %% [markdown]
# Ora diciamo che non è più possibile acquistare frazioni di gallone. (Ad esempio, se per realizzare un progetto occorrono 4,3 galloni, si dovranno acquistare 5 galloni di vernice).
#
# Con questo nuovo scenario, si creerà una nuova funzione get_actual_cost che utilizza gli stessi input e calcola il costo del progetto.
#
# Una funzione da utilizzare a tale scopo è math.ceil(). Nella cella di codice sottostante viene mostrato l'uso di questa funzione. Prende in input un numero e lo arrotonda al numero intero più vicino.

# %%
test_value = 2.17

rounded_value = math.ceil(test_value) # arrotonda sempre per eccesso
print(rounded_value)
# Out:
# 3

# %% [markdown]
# Utilizzare la cella di codice successiva per definire la funzione get_actual_cost(). A tale scopo è necessario utilizzare la funzione math.ceil().
#
# Nel rispondere a questa domanda, si noti che è assolutamente valido definire una funzione che fa uso di un'altra funzione. Per esempio, possiamo definire una funzione arrotondamento_e_divisione_per_tre che fa uso della funzione math.ceil:
#
# def round_up_and_divide_by_three(num):
#
#     nuovo_valore = math.ceil(num)
#     valore_finale = nuovo_valore / 3
#     restituire il valore finale

# %%
def get_actual_cost(sqft_walls, sqft_ceiling, sqft_per_gallon, cost_per_gallon):
    cost = math.ceil(((sqft_walls + sqft_ceiling)/sqft_per_gallon))*cost_per_gallon
    return cost
# stessa formula di prima ma con math.ceil per arrotondare, che va fatto prima di moltiplicare per il costo del gallone

# Check your answer
q5.check()
# Out:
# Correct

# %%
get_actual_cost(432, 144, 400, 15)
# Out:
# 30

# %%
get_actual_cost(594, 288, 400, 15)
# Out:
# 45
