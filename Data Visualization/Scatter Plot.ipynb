# %% [markdown]
# ## Scatter Plot
# In questo tutorial imparerai come creare grafici a dispersione avanzati.
#
# Come sempre, iniziamo configurando l'ambiente di codifica. (Questo codice è nascosto, ma puoi scoprirlo facendo clic sul pulsante "Codice" immediatamente sotto questo testo, a destra.)

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %% [markdown]
# Lavoreremo con un set di dati (sintetico) di spese assicurative, per vedere se riusciamo a capire perché alcuni clienti pagano più di altri.
# ![image.png](attachment:image.png)

# %%
# Path of the file to read
insurance_filepath = "D:/Users/Alessio/OneDrive/Python/Kaggle/Data Visualization/insurance.csv"

# Read the file into a variable insurance_data
insurance_data = pd.read_csv(insurance_filepath)

# %%
insurance_data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# ### Regressione Lineare
# Per creare un semplice **grafico a dispersione**, utilizziamo il comando sns.scatterplot e specifichiamo i valori per:
#
# - l'asse x orizzontale (x=insurance_data['bmi']), e
# - l'asse verticale delle y (y=insurance_data['addebiti']).

# %%
sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['charges'])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %% [markdown]
# Il grafico a dispersione sopra suggerisce che l'indice di massa corporea (BMI) e gli oneri assicurativi sono **correlati positivamente**, dove i clienti con un BMI più elevato in genere tendono anche a pagare di più i costi assicurativi. (Questo schema ha senso, poiché un BMI elevato è in genere associato a un rischio più elevato di malattie croniche.)
#
# Per ricontrollare la forza di questa relazione, potresti voler aggiungere una **linea di regressione** o la linea che meglio si adatta ai dati. Lo facciamo cambiando il comando in sns.regplot

# %%
sns.regplot(x=insurance_data['bmi'], y=insurance_data['charges'])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %% [markdown]
# ### Grafici a dispersione con codice colore
# Possiamo usare i grafici a dispersione per visualizzare le relazioni tra (non due, ma...) tre variabili! Un modo per farlo è codificare a colori i punti.
#
# Ad esempio, per capire come il fumo influisca sulla relazione tra BMI e costi assicurativi, possiamo codificare a colori i punti per "smoker" e tracciare le altre due colonne ("bmi", "charges") sugli assi.

# %%
sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['charges'], hue=insurance_data['smoker'])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %% [markdown]
# Questo grafico a dispersione mostra che mentre i non fumatori tendono a pagare leggermente di più con l'aumento del BMI, i fumatori pagano MOLTO di più.
#
# Per enfatizzare ulteriormente questo fatto, possiamo usare il comando `sns.lplot` per aggiungere due linee di regressione, corrispondenti a fumatori e non fumatori. (Noterai che la linea di regressione per i fumatori ha una pendenza molto più ripida, rispetto alla linea per i non fumatori!)

# %%
sns.lmplot(x="bmi", y="charges", hue="smoker", data=insurance_data)

# %% [markdown]
# Il comando sns.lplot sopra funziona in modo leggermente diverso rispetto ai comandi che hai imparato finora:
#
# Invece di impostare `x=insurance_data['bmi']` per selezionare la colonna 'bmi' in Insurance_data, impostiamo `x="bmi"` per specificare solo il nome della colonna.
# Allo stesso modo, `y="charges"` e `hue="smoker"` contengono anche i nomi delle colonne.
# Specifichiamo il set di dati con `data=insurance_data`.
# Infine, c'è un'altra trama che imparerai, che potrebbe sembrare leggermente diversa da come sei abituato a vedere le trame a dispersione. Di solito, utilizziamo grafici a dispersione per evidenziare la relazione tra due variabili continue (come "bmi" e "charges"). Tuttavia, possiamo adattare il design del grafico a dispersione per presentare una variabile categoriale (come "smoker") su uno degli assi principali. Ci riferiremo a questo tipo di grafico come a un **grafico a dispersione categoriale** e lo creeremo con il comando `sns.swarmplot`.

# %%
sns.swarmplot(x=insurance_data['smoker'],
              y=insurance_data['charges'])
# Out:
# E:\Users\Alessio\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 67.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='smoker', ylabel='charges'>

# %% [markdown]
# Tra le altre cose, questa trama ci mostra che:
#
# - in media, i non fumatori pagano meno dei fumatori e
# - i clienti che pagano di più sono i fumatori; mentre i clienti che pagano di meno sono non fumatori.

# %% [markdown]
# ## Esercizi
# In questo esercizio utilizzerai le tue nuove conoscenze per proporre una soluzione a uno scenario reale. Per avere successo, dovrai importare i dati in Python, rispondere alle domande utilizzando i dati e generare grafici a dispersione per comprendere i modelli nei dati.
#
# Lavori per un importante produttore di caramelle e il tuo obiettivo è scrivere un rapporto che la tua azienda possa utilizzare per guidare la progettazione del suo prossimo prodotto. Subito dopo aver iniziato la tua ricerca, ti imbatti in questo set di dati molto interessante contenente i risultati di un divertente sondaggio sulle caramelle preferite dal crowdsourcing.
#
# Esegui la cella successiva per importare e configurare le librerie Python necessarie per completare l'esercizio.

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %% [markdown]
# Le domande seguenti ti daranno un feedback sul tuo lavoro. Esegui la cella seguente per configurare il nostro sistema di feedback.

# %% [raw]
# # Set up code checking
# import os
# if not os.path.exists("D:/Users/Alessio/OneDrive/Python/Kaggle/Data Visualization/candy.csv"):
#     os.symlink("D:/Users/Alessio/OneDrive/Python/Kaggle/Data Visualization/candy.csv", "D:/Users/Alessio/OneDrive/Python/Kaggle/Data Visualization/candy.csv")
# from learntools.core import binder
# binder.bind(globals())
# from learntools.data_viz_to_coder.ex4 import *
# print("Setup Complete")

# %% [markdown]
# ### Domanda 1
# **Carica i dati**
#
# Leggi il file di dati delle caramelle in `candy_data`. Usa la colonna `"id"` per etichettare le righe.

# %%
# Path of the file to read
candy_filepath = "D:/Users/Alessio/OneDrive/Python/Kaggle/Data Visualization/candy.csv"

# Fill in the line below to read the file into a variable candy_data
candy_data = pd.read_csv(candy_filepath, index_col="id")

# Run the line below with no changes to check that you've loaded the data correctly
# step_1.check()

# %% [markdown]
# ### Domanda 2
# **Rivedere i dati**
#
# Usa un comando Python per stampare le prime cinque righe dei dati.

# %%
# Print the first five rows of the data
candy_data # Your code here
# Out:
#                 competitorname chocolate fruity caramel peanutyalmondy nougat  \
# id
# 0                    100 Grand       Yes     No     Yes             No     No
# 1                 3 Musketeers       Yes     No      No             No    Yes
# 2                    Air Heads        No    Yes      No             No     No
# 3                   Almond Joy       Yes     No      No            Yes     No
# 4                    Baby Ruth       Yes     No     Yes            Yes    Yes
# ..                         ...       ...    ...     ...            ...    ...
# 78                   Twizzlers        No    Yes      No             No     No
# 79                    Warheads        No    Yes      No             No     No
# 80        Welch's Fruit Snacks        No    Yes      No             No     No
# 81  Werther's Original Caramel        No     No     Yes             No     No
# 82                    Whoppers       Yes     No      No             No     No
#
# ...

# %% [markdown]
# Il set di dati contiene 83 righe, in cui ciascuna corrisponde a una diversa barretta di cioccolato. Ci sono 13 colonne:
# - `'nomeconcorrente'` contiene il nome della barretta di cioccolato.
# - le successive **9** colonne (da `'chocolate'` a `'pluribus'`) descrivono le caramelle. Ad esempio, le righe con le caramelle al cioccolato hanno `"Yes"` nella colonna `'chocolate'` (e le caramelle senza cioccolato hanno `"No"` nella stessa colonna).
# - `'sugarpercent'` fornisce qualche indicazione della quantità di zucchero, dove valori più alti indicano un contenuto di zucchero più elevato.
# - `'pricepercent'` mostra il prezzo per unità, relativo alle altre caramelle nel set di dati.
# - `'winpercent'` viene calcolato dai risultati del sondaggio; valori più alti indicano che la caramella era più popolare tra gli intervistati.
#
# Utilizza le prime cinque righe dei dati per rispondere alle domande seguenti.

# %%
# Print the first five rows of the data
candy_data.head()
# Which candy was more popular with survey respondents:
# '3 Musketeers' or 'Almond Joy'?
more_popular = '3 Musketeers'
# Which candy has higher sugar content: 'Air Heads'
# or 'Baby Ruth'?
more_sugar = 'Air Heads'

# Check your answers
# step_2.check()

# %% [markdown]
# ## Domanda 3
# **Il ruolo dello zucchero**
#
# Le persone tendono a preferire le caramelle con un contenuto di zucchero più elevato?
#
#
# Creare un grafico a dispersione che mostri la relazione tra `'sugarpercent'` (sull'asse x orizzontale) e `'winpercent'` (sull'asse y verticale). _Non aggiungere ancora una linea di regressione: lo farai nel passaggio successivo!_

# %%
# Scatter plot showing the relationship between 'sugarpercent' and 'winpercent'
sns.scatterplot(x=candy_data['sugarpercent'], y=candy_data['winpercent'])

# Check your answer
#step_3.a.check()
# Out:
# <AxesSubplot:xlabel='sugarpercent', ylabel='winpercent'>

# %% [markdown]
# Il grafico a dispersione mostra una forte correlazione tra le due variabili? In tal caso, le caramelle con più zucchero sono relativamente più o meno apprezzate dagli intervistati?

# %% [markdown]
# The scatter plot does not show a strong correlation between the two variables. Since there is no clear relationship between the two variables, this tells us that sugar content does not play a strong role in candy popularity.

# %% [markdown]
# ### Domanda 4
# **Dai un'occhiata più da vicino**
#
# Crea lo stesso grafico a dispersione che hai creato nel **Passaggio 3**, ma ora con una linea di regressione!

# %%
# Scatter plot w/ regression line showing the relationship between 'sugarpercent' and 'winpercent'
sns.regplot(x=candy_data['sugarpercent'], y=candy_data['winpercent'])
# Check your answer
#step_4.a.check()
# Out:
# <AxesSubplot:xlabel='sugarpercent', ylabel='winpercent'>

# %% [markdown]
# Secondo la trama sopra, esiste una **lieve** correlazione tra `'winpercent'` e `'sugarpercent'`? Cosa ti dice questo sulle caramelle che le persone tendono a preferire?

# %% [markdown]
# Since the regression line has a slightly positive slope, this tells us that there is a slightly positive correlation between `'winpercent'` and `'sugarpercent'`. Thus, people have a slight preference for candies containing relatively more sugar.

# %% [markdown]
# ### Domanda 5
# **Chocolate!**
#
# Nella cella del codice sottostante, crea un grafico a dispersione per mostrare la relazione tra `'pricepercent'` (sull'asse x orizzontale) e `'winpercent'` (sull'asse y verticale). Usa la colonna `'cioccolato'` per codificare a colori i punti. _Non aggiungere ancora linee di regressione: lo farai nel passaggio successivo!_

# %%
# Scatter plot showing the relationship between 'pricepercent', 'winpercent', and 'chocolate'
sns.scatterplot(x=candy_data['pricepercent'], y=candy_data['winpercent'], hue=candy_data['chocolate'])

# Check your answer
# step_5.check()
# Out:
# <AxesSubplot:xlabel='pricepercent', ylabel='winpercent'>

# %% [markdown]
# Riesci a vedere degli schemi interessanti nel grafico a dispersione? Esamineremo ulteriormente questo grafico aggiungendo linee di regressione nel passaggio successivo!

# %% [markdown]
# ### Domanda 6
# **Indaga sul cioccolato**
#
# Crea lo stesso grafico a dispersione che hai creato nel **Passaggio 5**, ma ora con due linee di regressione, corrispondenti a (1) caramelle al cioccolato e (2) caramelle senza cioccolato.

# %%
# Color-coded scatter plot w/ regression lines
sns.lmplot(x="pricepercent", y="winpercent", hue="chocolate", data=candy_data)

# Check your answer
#step_6.a.check()

# %% [markdown]
# Usando le linee di regressione, quali conclusioni puoi trarre sugli effetti del cioccolato e del prezzo sulla popolarità delle caramelle?

# %% [markdown]
# We'll begin with the regression line for chocolate candies. Since this line has a slightly positive slope, we can say that more expensive chocolate candies tend to be more popular (than relatively cheaper chocolate candies). Likewise, since the regression line for candies without chocolate has a negative slope, we can say that if candies don't contain chocolate, they tend to be more popular when they are cheaper. One important note, however, is that the dataset is quite small -- so we shouldn't invest too much trust in these patterns! To inspire more confidence in the results, we should add more candies to the dataset.

# %% [markdown]
# ### Domanda 7
# **Tutti amano il cioccolato.**
#
# Crea un grafico a dispersione categoriale per evidenziare la relazione tra `'chocolate'` e `'winpercent'`. Metti `'chocolate'` sull'asse x (orizzontale) e `'winpercent'` sull'asse y (verticale).

# %%
# Scatter plot showing the relationship between 'chocolate' and 'winpercent'
sns.swarmplot(x=candy_data['chocolate'], y=candy_data['winpercent'])
# Check your answer
#step_7.a.check()
# Out:
# <AxesSubplot:xlabel='chocolate', ylabel='winpercent'>

# %% [markdown]
# Decidi di dedicare una sezione della tua relazione al fatto che le caramelle al cioccolato tendono ad essere più popolari delle caramelle senza cioccolato. Quale trama è più appropriata per raccontare questa storia: la trama del passaggio 6 o la trama del passaggio 7?

# %% [markdown]
# In this case, the categorical scatter plot from Step 7 is the more appropriate plot. While both plots tell the desired story, the plot from Step 6 conveys far more information that could distract from the main point.
